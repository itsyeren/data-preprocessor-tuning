# %% [markdown]
# # Preprocessor Tuning

# %% [markdown]
# ## (0) `tumors` Dataset

# %% [markdown]
# * 👩🏻‍⚕️ The following dataset describes tumors that are either <font color=red>malignant</font> or <font color=green>benign</font>.
# * 🎯 The goal is to detect as many <font color=red>malignant</font> tumors as possible.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

url = "https://d32aokrjazspmn.cloudfront.net/materials/tumors_dataset.csv"
data = pd.read_csv(url)

data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34             NaN     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
round(data.malignant.value_counts(normalize = True),2)
# Out:
# malignant
# 0    0.63
# 1    0.37
# Name: proportion, dtype: float64

# %% [markdown]
# ## (1) Building a Pipeline

# %% [markdown]
# ❓ **Question: Building a Pipeline** ❓
#
# Combine the following steps into a **`Pipeline`** object named `pipeline`:
#
# 1. Impute missing values with **`KNNImputer`**
# 2. Scale all (numerical) features with **`MinMaxScaler`**
# 3. Fit a **`LogisticRegression`** model with default parameters

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ("imputer", KNNImputer()),
    ("scaler", MinMaxScaler()),
    ("logistic_regression", LogisticRegression())
])

pipeline
# Out:
# Pipeline(steps=[('imputer', KNNImputer()), ('scaler', MinMaxScaler()),
#                 ('logistic_regression', LogisticRegression())])

# %% [markdown]
# ## (2) Optimizing the Pipeline Model

# %% [markdown]
# ❓ **Question (GridSearch on a Pipeline)** ❓
#
# * What is the **best number of neighbors** for the KNN imputer: **2, 5, or 10**?
#     * Run a **GridSearch** on your pipeline and store the answer in a variable called `n_best`.
#     * _Note: Make sure to use a **relevant scoring metric** for the task during Grid Search — just a heads up 🙂_
# * Feel free to run the **GridSearch on the entire dataset** instead of using a train/test split for this challenge. The goal here is simply to **get comfortable with Pipelines** 🙂

# %%
n_best = None

# %%
from sklearn.model_selection import GridSearchCV

gridsearch = GridSearchCV(
    pipeline,
    param_grid={'imputer__n_neighbors': [2, 5, 10]},
    cv=5,
    scoring="recall",
)

gridsearch.fit(data.drop(columns="malignant"), data['malignant'])

gridsearch.best_params_
# Out:
# {'imputer__n_neighbors': 5}

# %%
n_best = gridsearch.best_params_["imputer__n_neighbors"]
n_best
# Out:
# 5

# %% [markdown]
# ## (3) Evaluating the Pipeline

# %% [markdown]
# ❓ **Question: What is the performance of the best pipeline?** ❓
#
# - Make sure to evaluate your best pipeline using **cross-validation**!
# - Store the result as a **float** in a variable called `cv_score`

# %%
cv_score = None

# %%
from sklearn.model_selection import cross_val_score

cv_score = cross_val_score(
    gridsearch.best_estimator_, 
    data.drop(columns="malignant"),
    data['malignant'], 
    cv=5,
    scoring="recall"
    ).mean()

cv_score
# Out:
# 0.9244739756367663

# %%
from nbresult import ChallengeResult

result = ChallengeResult(
    'solution', 
    n_best = n_best,
    cv_score=cv_score
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/yaren/.pyenv/versions/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/yaren/code/ds_projects/data-preprocessor-tuning/tests
# plugins: anyio-4.12.1, dash-4.0.0, typeguard-4.4.2
# collecting ... collected 2 items
#
# test_solution.py::TestSolution::test_n_neighbours PASSED                 [ 50%]
# test_solution.py::TestSolution::test_score_good_enough PASSED            [100%]
#
# ============================== 2 passed in 0.51s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/solution.pickle
#
# git commit -m 'Completed solution step'
#
# git push origin master

# %% [markdown]
# ## (4) Making predictions with a trained and pipelined model

# %% [markdown]
# 👇 Here is a new tumor.

# %%
new_url = "https://d32aokrjazspmn.cloudfront.net/materials/new_tumor.csv"

new_data = pd.read_csv(new_url)
new_data
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.05667        0.5435         0.7339            3.398
#
#    area error  smoothness error  compactness error  concavity error  \
# 0       74.08          0.005225            0.01308           0.0186
#
#    concave points error  symmetry error  fractal dimension error  \
# 0                0.0134         0.01389                 0.003532
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         24.99          23.41            158.8      1956.0            0.1238
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# ...

# %% [markdown]
# ❓ **Question: Use your best (optimal) pipeline to predict whether the new tumor is malignant** ❓

# %%
gridsearch.best_estimator_.predict(new_data)
# Out:
# array([1])

# %%
gridsearch.best_estimator_.predict_proba(new_data)
# Out:
# array([[0.03203546, 0.96796454]])
